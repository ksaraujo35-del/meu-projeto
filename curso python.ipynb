# %%
nome = input( 'qual seu nome?')
# Out:
# qual seu nome?

# %% [raw]
# idade = int(input('qual sua idade'))

# %%
print(idade)
# Out:
# 35

# %%
print(type(nome))
# Out:
# <class 'str'>

# %%
print('Ola ' , idade)
# Out:
# Ola  35

# %% [raw]
# print( 'voce este velho', idade)

# %%
print( 'voce este velho', idade)
# Out:
# voce este velho 35

# %%
quant_apt = int (input('quantos apartamentos existem:'))
valor_agua = float (input (' valor da água'))
valor_energia =float(input (' valor da energia'))

valor_rateio =(valor_agua + valor_energia) /quant_apt

print (f' O valor do rateio é: R$ {valor_rateio:.2f} ')

# %%
a = int(input('digite o primeiro numero'))
b = int(input(' digite o segundo numero'))
soma = a + b
subtracao = a- b
print(' A soma é ' , soma , 'A subtraçao é ', subtracao )
# Out:
# digite o primeiro numero 1
#  digite o segundo numero 4
#  A soma é  5 A subtraçao é  -3

# %%
print(' A multiplicaçao é ',a*b)
# Out:
#  A multiplicaçao é  4

# %%
salario_bruto = float(input('salario bruto recebido:'))
valor_ir = salario_bruto*0.05
valor_inss = salario_bruto*0.11
salario_liquido = salario_bruto - valor_ir - valor_inss
print (f' O salario liquido é: R$ {salario_liquido:.2f}' )

# %%
#entrada
a= int(input('insira o primeiro valor:'))
b =int(input('insira o segundo valor:'))
#saida
print(' A soma dos valores é:', soma)
# Out:
# insira o primeiro valor: 15
# insira o segundo valor: 12
#  A soma dos valores é: 5

# %%
#entrada
salario_base = float(input ('digite o salario base'))
vantagens = float(input('digite vantage'))
desconto = float(input('digite desconto'))
salario_liq = salario_base+vantagens-desconto
print (salario_liq)
# Out:
# digite o salario base 1000
# digite vantage 30
# digite desconto 20
# 1010.0

# %%
juros = salario_liq* 0.06
print( ' se investir no mercado  ' , salario_liq * 0.06)
# Out:
#  se investir no mercado   60.599999999999994

# %%
nota1 = float(input ('insira nota:'))
nota2 = float(input (' insira a nota:'))
media = (nota1 + nota2)/2
print(media)
# Out:
# insira nota: 8.5
#  insira a nota: 9.2
# 8.85

# %%
if media >= 7:
    print(' aprovado' ),
else:
    print(' reprovado')
# Out:
#  aprovado

# %% [raw]
# #salario fixo de um vendedor

# %%
salario_fixo = float(input('salario fixo'))
total_vendas = float(input('total_vendas'))
salario_total = salario_fixo +0.15*total_vendas
print(' o salario total:', salario_total)
# Out:
# salario fixo 15000
# total_vendas 2000
#  o salario total: 15300.0

# %%
#conversao real dolar

# %%
valor_real = float(input(' real'))
valor_dolar = float(input( 'dolar'))
conversao = valor_real* 5.37
print(' valor convertido:',conversao)
# Out:
#  real 100
# dolar 120
#  valor convertido: 537.0
